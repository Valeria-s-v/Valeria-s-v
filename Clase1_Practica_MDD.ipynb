# %% [markdown]
# <a href="https://colab.research.google.com/github/Valeria-s-v/Valeria-s-v/blob/main/Clase1_Practica_MDD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Código con Pandas
# ![image.png](data:image/png;base64,...)

# %%
# !pip install pandas

# %%
import pandas as pd

# URL del dataset Titanic
url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
print(url)
# Out:
# https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv

# %%
# Cargar el dataset directamente desde la URL
df = pd.read_csv(url)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Mostar los tipos de datos de cada columna
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
#Mostrar la cantidad total de datos
df.size
#Motrar cantidad total de filas
df.shape[0]
# Out:
# 891

# %%
#Cambiar el tipo de Datos de alguna columna
df['Age'] = df['Age'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# <ipython-input-57-a2acad9d3466> in <cell line: 0>()
#       1 #Cambiar el tipo de Datos de alguna columna
# ----> 2 df['Age'] = df['Age'].astype(int)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6641         else:
#    6642             # else, only a single dtype is given
# -> 6643             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644             res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645             return res.__finalize__(self, method="astype")
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     428             copy = False
#     429
# --> 430         return self.apply(
#     431             "astype",
# ...

# %%
#Mostrar las columnas categoricas
df.select_dtypes(include=['object']).columns
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
#Mostrar la cantidad de Nulos
df.isnull().sum()
#Eliminamos los valores nulos de la columna Age
df.dropna(subset=['Age'], inplace=True)
#df.dropna(inplace=True)

# %%
df.shape[0]
# Out:
# 714

# %%
#Realizar un grafico de histograma de la columna Age
import matplotlib.pyplot as plt
df['Age'].hist()
plt.show()

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#Reemplazar los valores nulos por el valor de la media
df['Age'].fillna(df['Age'].mean(), inplace=True)
#Reemplazar los valores nulos por el valor de la mediana

#df['Age'].fillna(df['Age'].mode()[0], inplace=True)

# %%
df['Age'].fillna(df['Age'].median(), inplace=True)
#Reemplazar los valores nulos por el valor de la moda
# Out:
# <ipython-input-63-40d7a2ffbec2>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].median(), inplace=True)

# %%
#Realizar un grafico de histograma de la columna Age
import matplotlib.pyplot as plt
df['Age'].hist()
plt.show()

# %%
# Filtrar filas donde la columna 'Age' es mayor que 30
filtered_df = df[df['Age'] > 30]

# Seleccionar columnas 'Name' y 'Age'
selected_columns = filtered_df[['Name', 'Age']]
selected_columns
# Out:
#                                                   Name   Age
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                             Allen, Mr. William Henry  35.0
# 6                              McCarthy, Mr. Timothy J  54.0
# 11                            Bonnell, Miss. Elizabeth  58.0
# ..                                                 ...   ...
# 873                        Vander Cruyssen, Mr. Victor  47.0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  56.0
# 881                                 Markun, Mr. Johann  33.0
# 885               Rice, Mrs. William (Margaret Norton)  39.0
# 890                                Dooley, Mr. Patrick  32.0
#
# [305 rows x 2 columns]

# %%
#Realizar un grafico de histograma de la columna Age
import matplotlib.pyplot as plt
df['Age'].hist()
plt.show()

# %%
# Calcular el promedio de la columna 'Age'
mean_age = selected_columns['Age'].mean()

print(mean_age)
# Out:
# 42.927868852459014

# %% [markdown]
# #Código con Polars
# https://pola.rs/

# %%
import polars as pl

# URL del dataset Titanic
url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"

# Cargar el dataset directamente desde la URL
df = pl.read_csv(url)
df
# Out:
# shape: (891, 12)
# ┌─────────────┬──────────┬────────┬──────────────────┬───┬────────────┬─────────┬───────┬──────────┐
# │ PassengerId ┆ Survived ┆ Pclass ┆ Name             ┆ … ┆ Ticket     ┆ Fare    ┆ Cabin ┆ Embarked │
# │ ---         ┆ ---      ┆ ---    ┆ ---              ┆   ┆ ---        ┆ ---     ┆ ---   ┆ ---      │
# │ i64         ┆ i64      ┆ i64    ┆ str              ┆   ┆ str        ┆ f64     ┆ str   ┆ str      │
# ╞═════════════╪══════════╪════════╪══════════════════╪═══╪════════════╪═════════╪═══════╪══════════╡
# │ 1           ┆ 0        ┆ 3      ┆ Braund, Mr. Owen ┆ … ┆ A/5 21171  ┆ 7.25    ┆ null  ┆ S        │
# │             ┆          ┆        ┆ Harris           ┆   ┆            ┆         ┆       ┆          │
# │ 2           ┆ 1        ┆ 1      ┆ Cumings, Mrs.    ┆ … ┆ PC 17599   ┆ 71.2833 ┆ C85   ┆ C        │
# │             ┆          ┆        ┆ John Bradley     ┆   ┆            ┆         ┆       ┆          │
# ...

# %%
# Filtrar filas donde la columna 'Age' es mayor que 30
filtered_df = df.filter(pl.col('Age') > 30)

# Seleccionar columnas 'Name' y 'Age'
selected_columns = filtered_df.select(['Name', 'Age'])

# Calcular el promedio de la columna 'Age'
mean_age = selected_columns['Age'].mean()

print(mean_age)
